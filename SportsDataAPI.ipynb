# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
from datetime import date
import requests
import io

# %%
headers = {"Ocp-Apim-Subscription-Key":"46c36d2610f74bfcbb40805d806c0907"}
url = 'https://api.sportsdata.io/v3/soccer/scores/json/Players'
x = requests.get(url, headers=headers).json()

# %%
type(x)
x[1]
# Out:
# {'PlayerId': 90026232,
#  'FirstName': 'Dan',
#  'LastName': 'Gosling',
#  'CommonName': 'Dan Gosling',
#  'ShortName': 'D. Gosling',
#  'Position': 'M',
#  'PositionCategory': 'M',
#  'Jersey': 4,
#  'Foot': 'Both',
#  'Height': 183,
#  'Weight': 79,
#  'Gender': 'Male',
#  'BirthDate': '1990-02-02T00:00:00',
#  'BirthCity': 'Brixham',
#  'BirthCountry': 'England',
#  'Nationality': 'England',
#  'InjuryStatus': 'Scrambled',
#  'InjuryBodyPart': 'Scrambled',
#  'InjuryNotes': 'Scrambled',
#  'InjuryStartDate': None,
#  'Updated': '2021-01-07T17:19:04',
#  'PhotoUrl': 'https://s3-us-west-2.amazonaws.com/static.fantasydata.com/headshots/soc/low-res/90026232.png',
#  'RotoWirePlayerID': 2011,
#  'DraftKingsPosition': 'M',
#  'UsaTodayPlayerID': None,
#  'UsaTodayHeadshotUrl': None,
#  'UsaTodayHeadshotNoBackgroundUrl': None,
#  'UsaTodayHeadshotUpdated': None,
#  'UsaTodayHeadshotNoBackgroundUpdated': None}

# %%
players = pd.DataFrame(x)

# %%
players.head()
# Out:
#    PlayerId FirstName   LastName        CommonName     ShortName Position  \
# 0  90026231    Junior  Stanislas  Junior Stanislas  J. Stanislas        M
# 1  90026232       Dan    Gosling       Dan Gosling    D. Gosling        M
# 2  90026233     Shaun  MacDonald   Shaun MacDonald  S. MacDonald        M
# 3  90026234      Adam      Smith        Adam Smith      A. Smith        D
# 4  90026235     Harry      Arter       Harry Arter      H. Arter        M
#
#   PositionCategory  Jersey   Foot  Height  ...  InjuryStartDate  \
# 0                M    19.0   Both   183.0  ...             None
# 1                M     4.0   Both   183.0  ...             None
# 2                M     4.0  Right   185.0  ...             None
# 3                D    15.0  Right   180.0  ...             None
# 4                M    31.0   Left   178.0  ...             None
#
#                Updated                                           PhotoUrl  \
# ...

# %%
df[df.LastName == 'Mane']
# Out:
#        PlayerId FirstName LastName   CommonName ShortName Position  \
# 45845  90072130    Malick     Mane  Malick Mane   M. Mane        A
#
#       PositionCategory  Jersey   Foot  Height  ...  InjuryStartDate  \
# 45845                A     NaN  Right   175.0  ...             None
#
#                    Updated                                           PhotoUrl  \
# 45845  2021-01-07T15:11:44  https://s3-us-west-2.amazonaws.com/static.fant...
#
#       RotoWirePlayerID DraftKingsPosition UsaTodayPlayerID  \
# 45845              NaN               None              NaN
#
#       UsaTodayHeadshotUrl UsaTodayHeadshotNoBackgroundUrl  \
# 45845                None                            None
#
#       UsaTodayHeadshotUpdated UsaTodayHeadshotNoBackgroundUpdated
# 45845                    None                                None
#
# [1 rows x 29 columns]
